# %% [markdown]
# # Capstone Project

# %% [markdown]
# I am going to write some notes related to capstone project

# %% [markdown]
# In fact, this notebook will be mainly used for the capstone project.

# %% [markdown]
# In summary, this capstone project will consist of five modules

# %%
import  pandas as pd

# %%
import  numpy  as np

# %%
print(" Hello Capstone Project Course!")
# Out:
#  Hello Capstone Project Course!
